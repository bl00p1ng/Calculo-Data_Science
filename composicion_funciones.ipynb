# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def g(x):
    return x**2


def f(x):
    return np.sin(x)

# f compuesta g
f_o_g = f(g(x))

x = np.linspace(-10, 10, num=100)

# Graficar
plt.plot(x, f_o_g)
plt.grid()
